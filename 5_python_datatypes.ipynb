# %% [markdown]
# <a href="https://colab.research.google.com/github/alijilani-dev/modern-ai-python/blob/main/5_python_datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://chatgpt.com/s/t_689879d1608c81918d48da0b456fb08b

# %% [markdown]
# **Immutable Types** 🪨 (Once made, can’t change)
# List: integer, float, bool, string, tuple, frozenset
#
# **Acronym:** *"I Feel Big Stones Turn Firm"*
#
# I → Integer
#
# Feel → Float
#
# Big → Bool
#
# Stones → String
#
# Turn → Tuple
#
# Firm → Frozenset
#
# **Mnemonic Story:**
# Imagine you’re hiking and say: *“I feel big stones turn firm under my feet.”*
# This reminds you that these things stay the same — just like immutable objects.
#
# **Mutable Types** 🧱 (Can be changed in place)
# List: List, Dictionary, Set
#
# **Acronym:** *"Little Ducks Swim (In Shallow Water)"*
#
# Little → List
#
# Ducks → Dictionary
#
# Swim → Set
#
# **Mnemonic Story:**
# Little ducks swim around freely, changing direction anytime — just like mutable objects change in place.
#
# **💡 Memory Hack:**
# *Think of Immutable as rocks (once formed, don’t change without breaking) and mutable as ducks (use duck tape; always moving and changing).*
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![5_python_datatypes_mutable.PNG](data:image/png;base64,...)
